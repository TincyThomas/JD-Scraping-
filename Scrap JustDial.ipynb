# %%
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())
import pandas as pd
import time
import os
# Out:
# [WDM] - Driver [C:\Users\Tincy\.wdm\drivers\geckodriver\win64\v0.28.0\geckodriver.exe] found in cache

# %%
# driver.get method() will navigate to a page given by the URL address
driver.get("https://www.justdial.com/Ernakulam/Building-Contractors/nct-10059338")

# %%
def strings_to_num(argument): 
    
    switcher = { 
        'dc': '+',
        'fe': '(',
        'hg': ')',
        'ba': '-',
        'acb': '0', 
        'yz': '1', 
        'wx': '2',
        'vu': '3',
        'ts': '4',
        'rq': '5',
        'po': '6',
        'nm': '7',
        'lk': '8',
        'ji': '9'
    } 
    
    return switcher.get(argument, "nothing")

# %%
storeDetails = driver.find_elements_by_class_name('store-details')
nameList = []
addressList = []
numbersList = []

for i in range(len(storeDetails)):
    
    name = storeDetails[i].find_element_by_class_name('lng_cont_name').text
    address = storeDetails[i].find_element_by_class_name('cont_fl_addr').get_attribute('innerHTML')
    contactList = storeDetails[i].find_elements_by_class_name('mobilesv')
    
    myList = []
    
    for j in range(len(contactList)):
        
        myString = contactList[j].get_attribute('class').split("-")[1]
    
        myList.append(strings_to_num(myString))

    nameList.append(name)
    addressList.append(address)
    numbersList.append("".join(myList))    
# intialise data of lists.
data = {'Company Name':nameList,
        'Address': addressList,
        'Phone':numbersList}
# Create DataFrame
df = pd.DataFrame(data)

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %%
df.to_csv('demo1.csv', mode='a', header=False)

# %%
df
# Out:
#                      Company Name  \
# 0        EC Builders & Developers
# 1                 CenTec Builders
# 2                 D-Arc Designers
# 3                    J P Ventures
# 4                Bahiya Interiors
# 5          Kakkanattu Contractors
# 6           Pulickal Construction
# 7            Deepam Constructions
# 8                     Paint World
# 9         Designtree Interior LLP
# 10            Arcade Construction
# 11              Raj Constructions
# 12  Perfect Designers and Engin..
# 13  Maharaja Engineers And Cont..
# 14                     Eagle Tech
# 15  Kreupas Construction Real W..
# 16  Anamika Designers and const..
# 17                 Bobs Interiors
# 18              Kottaram Builders
# 19                   Ornate Steel
# 20                   Salmia Group
# 21              Saju Construction
# 22              Saju Construction
# 23  A K Building Maintenance & ..
# 24               Tp Constructions
# 25  Tet Direction Construction ..
# 26      Green Castle Projects LLP
# 27                  Katic Designs
# 28                    Maria Homes
# 29  Trend INDIA Interiors And E..
# 30                 Bobs Interiors
# 31               Piravom Builders
# 32         Modern Dream Designing
# 33  Kottaram Builders And Devel..
# 34                     Le Concept
# 35       Amzer Infra Projects LLP
# 36    Ascon Builders Muvattupuzha
# 37              EVS Constructions
# 38                 Adora Builders
# 39             Johnson Associates
# 40                Smart Solutions
# 41              P R Constructions
# 42  Aisons Builders & Developer..
# 43          Adco Builders Pvt Ltd
# 44                 Jvn Propreties
# 45                    Grand Homes
# 46  Alpha Prime Engineering Sol..
# 47  Aiswarya Builders & Enginee..
# 48             Innovative Designs
# 49                         SKYARC
# 50                  Epic Devloper
# 51    Srishti Designs & Engineers
# 52               Anarkh Solutions
# 53  Durga Labour Manpower Suppl..
# 21     Aluva, Aluva, Ernakulam - 683101, Federal bank         07947271294
# 22  Pulinchodu, Aluva, Ernakulam - 683101, Near Pu...         07947271044
# 23      Edapally, Ernakulam - 682024, Near Icici Bank         07947372401
# 24  609/D, Sundarimukku Junction, Vennala, Ernakul...         07947271387
# 25  Vazhikulangara,, Paravur, Ernakulam - 683513, ...         07947269946
# 26    Panampilly Nagar, Ernakulam - 682036, Near Park         07947271372
# 27  No 4/283G, 1st Floor, Chakkappan Square, Parut...   +(91)-484-2575342
# 28  A M Road, Kothamangalam Ernakulam, Ernakulam -...         07947270558
# 29  Pallipadikkal, Kedamangalam, Paravur, Ernakula...   +(91)-484-6457903
# 30  Moozhithottil House, Eloor Road, Udyogamandal,...         07947269241
# 31  First Floor 7/471, Neelankal Building, Piravom...         07947061461
# 32  Medical College Road, Kolenchery, Ernakulam - ...    +(91)-9567563590
# 33  9/66, Premier Tower Shopping Complex, Aluva-Mu...    +(91)-9446451149
# 34  Muppathadam, Ernakulam - 683110, Oppsite Muthu...    +(91)-9995557661
# 35  Thamarassery Building, Cheranalloor Road, Koon...         07947270032
# 36  1st Floor, St Mary, Muvattupuzha Market, Ernak...    +(91)-9605591127
# 37  Vattoliparambil Complex, East  Kadungalloor, A...    +(91)-7025756027
# 38  Ace Kunjo Plaza 6th Floor, Market Road, Kacher...         07947271353
# 39  Thottungal House, Ajantha Road, Mattancherry, ...   +(91)-484-2210299
# 40  Samajam Road, Vaduthala, Ernakulam - 682022, D...    +(91)-9746714985
# 41        Chettibhagam, Varapuzha, Ernakulam - 683517    +(91)-9544987733
# 42  Perumbattu House ,, Kokkappilli, Thiruvamkulam...    +(91)-9846999018
# 43  VI/279G 1st Floor, Perumbavoor, Ernakulam - 68...   +(91)-484-2522952
# 44  Nedumchalil,Mudavoor Post, M C Road, Muvattupu...    +(91)-9388175544
# 45  A J Tower, Vaikom Road, Tripunithura, Ernakula...   +(91)-484-2242174
# 46             Angamaly, Ernakulam - 683573, Angamaly    +(91)-8939163680
# 47  Kalady Road, Angamaly, Ernakulam - 683572, Nea...    +(91)-9847083878
# 48  Olaprath House, Near Metro Police Station, Kal...    +(91)-9388628686
# 49  Aluva, Ernakulam - 683101, Opposite Casino The...    +(91)-9961486624
# 50  Priyanandana Commercial Centre, Aluva, Ernakul...    +(91)-7012498874
# 51  42/1129-B, Edappally Arkakadavu Road, Vennala,...   +(91)-484-2809071
# 52        Desabimani Road, Kaloor, Ernakulam - 682017    +(91)-9895775699
# 53  Bhagavathi Rao Sakkuri 26-20-7 Majisti Varivee...    +(91)-7866075578
# 54  611/612, Nirmal Corporate Center, L B S Marg, ...   +(91)-22-25674690
# 55  Room No 7, DCMS Complex, R F Road, Anantapur H...  +(91)-08554-226233
# 56  11/2275, BYPASS ROAD NEAR BUSTAND EDAVANNAPARA...    +(91)-9746088020
# 57  No 58/1 NH44, Bangalore Byepass, Thumbipadi, S...         07947264320
# 58  Madhyamam Road, Maradu, Ernakulam - 682304, Ne...    +(91)-9947592227
# 59  N0 : 1,, Rajiv Gandhi Nagar, Sugarcane Breedin...         07947263019
